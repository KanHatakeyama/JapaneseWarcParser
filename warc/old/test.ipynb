# %%
# %reload_ext autoreload
# %autoreload 2

from src.file_utils import download_file, decompress_gz,make_dir
import glob
from warcio.archiveiterator import ArchiveIterator
from bs4 import BeautifulSoup
from tqdm import tqdm
from src.parse_warc import extract_japanese_from_warc

import json
import gzip

# %%
json_path_list=glob.glob('data/gz/*.gz')
len(json_path_list)
# Out:
# 528

# %%
path="data/jap_dump/crawl-data_CC-MAIN-2023-50_segments_1700679099281.67_warc_CC-MAIN-20231128083443-20231128113443-00000.warc_jap.gz.gz"
# gzipで圧縮されたJSONファイルを読み込み
with gzip.open(path, 'rt', encoding='utf-8') as f:
    data_loaded = json.load(f)

# %%
data_loaded[0]
# Out:
# {'record_id': 69,
#  'url': 'http://1pachi-search.com/kensaku/%E9%95%B7%E5%B4%8E/%E8%A5%BF%E5%BD%BC%E6%9D%B5%E9%83%A1/017088.php',
#  'title': 'ラッキーランド時津店 西彼杵郡 1円パチンコ・5円スロット',
#  'timestamp': '2023-11-28T09:13:06Z',
#  'text': [['ラッキーランド時津店 西彼杵郡 1円パチンコ・5円スロット', 'html'],
#   ['1円パチンコサーチ', 'html'],
#   ['toggle navigation', 'html'],
#   ['1円パチンコ設置店・換金率', 'html'],
#   ['1円パチンコボーダー', 'html'],
#   ['収支日記', 'html'],
#   ['換金率調査', 'html'],
#   ['1円パチンコサーチTOP', 'html'],
#   ['1円パチンコ設置店', 'html'],
#   ['長崎', 'html'],
#   ['西彼杵郡', 'html'],
#   ['ラッキーランド時津店', 'html'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'html'],
#   ['ラッキーランド時津店', 'html'],
#   ['パチンコ', 'html'],
#   ['0.5円', 'html'],
#   ['1円', 'html'],
#   ['2円', 'html'],
#   ['-', 'html'],
#   ['-', 'html'],
#   ['○', 'html'],
#   ['スロット', 'html'],
#   ['2円', 'html'],
#   ['5円', 'html'],
#   ['10円', 'html'],
#   ['-', 'html'],
#   ['-', 'html'],
#   ['○', 'html'],
#   ['換金率(交換率)', 'html'],
#   ['備考', 'html'],
#   ['関連リンク', 'html'],
#   ['口コミを投稿する', 'html'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'html'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'html'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'html'],
#   ['お名前', 'html'],
#   ['口コミ本文', 'html'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'html'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'html'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。', 'html'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'html'],
#   ['是非、ご利用ください。', 'html'],
#   ['1円パチンコサーチ携帯版', 'html'],
#   ['http://1pachi-search.com/mobile/', 'html'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'html'],
#   ['西彼杵郡一覧へ', 'html'],
#   ['長崎 エリア', 'html'],
#   ['エリア一覧', 'html'],
#   ['長崎市', 'html'],
#   ['佐世保市', 'html'],
#   ['島原市', 'html'],
#   ['諌早市', 'html'],
#   ['大村市', 'html'],
#   ['松浦市', 'html'],
#   ['対馬市', 'html'],
#   ['壱岐市', 'html'],
#   ['五島市', 'html'],
#   ['西海市', 'html'],
#   ['雲仙市', 'html'],
#   ['南島原市', 'html'],
#   ['西彼杵郡', 'html'],
#   ['東彼杵郡', 'html'],
#   ['北松浦郡', 'html'],
#   ['南松浦郡', 'html'],
#   ['都道府県選択へ', 'html'],
#   ['新規店舗登録', 'html'],
#   ['■AD', 'html'],
#   ['おすすめコンテンツ', 'html'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'html'],
#   ['ハーデス', 'html'],
#   ['アプリ配信中', 'html'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'html'],
#   ['CRリング アプリ', 'html'],
#   ['バジリスク絆', 'html'],
#   ['アプリ配信中', 'html'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'html'],
#   ['（端末拡大版）', 'html'],
#   ['ジャグラーアプリ', 'html'],
#   ['スロアプリ配信中', 'html'],
#   ['1円パチンコや5円スロットをホールで実践する前に、アプリやメーカー公認サイトなどでシミュレーションしてみてはいかがでしょうか。', 'html'],
#   ['1円パチンコであれば普段ホールで打てないような釘状態での遊戯体験や、5円スロットであればなかなかお目にかかれない設定6での実践体験が可能です！',
#    'html'],
#   ['実際にホールで遊戯した後に実践の復習として使ってみても良いかもしれません。', 'html'],
#   ['ツイート', 'html'],
#   ['利用規約', 'html'],
#   ['｜', 'html'],
#   ['リンク', 'html'],
#   ['｜', 'html'],
#   ['お問い合わせ', 'html'],
#   ['© 2010-2022 1円パチンコサーチ All rights reserved.', 'html'],
#   ['TOP', 'html'],
#   ['ラッキーランド時津店 西彼杵郡 1円パチンコ・5円スロット', 'head'],
#   ['ラッキーランド時津店 西彼杵郡 1円パチンコ・5円スロット', 'meta'],
#   ['ラッキーランド時津店 西彼杵郡 1円パチンコ・5円スロット', 'title'],
#   ['1円パチンコサーチ', 'body'],
#   ['toggle navigation', 'body'],
#   ['1円パチンコ設置店・換金率', 'body'],
#   ['1円パチンコボーダー', 'body'],
#   ['収支日記', 'body'],
#   ['換金率調査', 'body'],
#   ['1円パチンコサーチTOP', 'body'],
#   ['1円パチンコ設置店', 'body'],
#   ['長崎', 'body'],
#   ['西彼杵郡', 'body'],
#   ['ラッキーランド時津店', 'body'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'body'],
#   ['ラッキーランド時津店', 'body'],
#   ['パチンコ', 'body'],
#   ['0.5円', 'body'],
#   ['1円', 'body'],
#   ['2円', 'body'],
#   ['-', 'body'],
#   ['-', 'body'],
#   ['○', 'body'],
#   ['スロット', 'body'],
#   ['2円', 'body'],
#   ['5円', 'body'],
#   ['10円', 'body'],
#   ['-', 'body'],
#   ['-', 'body'],
#   ['○', 'body'],
#   ['換金率(交換率)', 'body'],
#   ['備考', 'body'],
#   ['関連リンク', 'body'],
#   ['口コミを投稿する', 'body'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'body'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'body'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'body'],
#   ['お名前', 'body'],
#   ['口コミ本文', 'body'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'body'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'body'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。', 'body'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'body'],
#   ['是非、ご利用ください。', 'body'],
#   ['1円パチンコサーチ携帯版', 'body'],
#   ['http://1pachi-search.com/mobile/', 'body'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'body'],
#   ['西彼杵郡一覧へ', 'body'],
#   ['長崎 エリア', 'body'],
#   ['エリア一覧', 'body'],
#   ['長崎市', 'body'],
#   ['佐世保市', 'body'],
#   ['島原市', 'body'],
#   ['諌早市', 'body'],
#   ['大村市', 'body'],
#   ['松浦市', 'body'],
#   ['対馬市', 'body'],
#   ['壱岐市', 'body'],
#   ['五島市', 'body'],
#   ['西海市', 'body'],
#   ['雲仙市', 'body'],
#   ['南島原市', 'body'],
#   ['西彼杵郡', 'body'],
#   ['東彼杵郡', 'body'],
#   ['北松浦郡', 'body'],
#   ['南松浦郡', 'body'],
#   ['都道府県選択へ', 'body'],
#   ['新規店舗登録', 'body'],
#   ['■AD', 'body'],
#   ['おすすめコンテンツ', 'body'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'body'],
#   ['ハーデス', 'body'],
#   ['アプリ配信中', 'body'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'body'],
#   ['CRリング アプリ', 'body'],
#   ['バジリスク絆', 'body'],
#   ['アプリ配信中', 'body'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'body'],
#   ['（端末拡大版）', 'body'],
#   ['ジャグラーアプリ', 'body'],
#   ['スロアプリ配信中', 'body'],
#   ['1円パチンコや5円スロットをホールで実践する前に、アプリやメーカー公認サイトなどでシミュレーションしてみてはいかがでしょうか。', 'body'],
#   ['1円パチンコであれば普段ホールで打てないような釘状態での遊戯体験や、5円スロットであればなかなかお目にかかれない設定6での実践体験が可能です！',
#    'body'],
#   ['実際にホールで遊戯した後に実践の復習として使ってみても良いかもしれません。', 'body'],
#   ['ツイート', 'body'],
#   ['利用規約', 'body'],
#   ['｜', 'body'],
#   ['リンク', 'body'],
#   ['｜', 'body'],
#   ['お問い合わせ', 'body'],
#   ['© 2010-2022 1円パチンコサーチ All rights reserved.', 'body'],
#   ['TOP', 'body'],
#   ['1円パチンコサーチ', 'header'],
#   ['toggle navigation', 'header'],
#   ['1円パチンコサーチ', 'div'],
#   ['1円パチンコサーチ', 'div'],
#   ['1円パチンコサーチ', 'a'],
#   ['1円パチンコサーチ', 'span'],
#   ['toggle navigation', 'button'],
#   ['toggle navigation', 'span'],
#   ['1円パチンコ設置店・換金率', 'div'],
#   ['1円パチンコボーダー', 'div'],
#   ['収支日記', 'div'],
#   ['換金率調査', 'div'],
#   ['1円パチンコ設置店・換金率', 'nav'],
#   ['1円パチンコボーダー', 'nav'],
#   ['収支日記', 'nav'],
#   ['換金率調査', 'nav'],
#   ['1円パチンコ設置店・換金率', 'ul'],
#   ['1円パチンコボーダー', 'ul'],
#   ['収支日記', 'ul'],
#   ['換金率調査', 'ul'],
#   ['1円パチンコ設置店・換金率', 'li'],
#   ['1円パチンコ設置店・換金率', 'a'],
#   ['1円パチンコボーダー', 'li'],
#   ['1円パチンコボーダー', 'a'],
#   ['収支日記', 'li'],
#   ['収支日記', 'a'],
#   ['換金率調査', 'li'],
#   ['換金率調査', 'a'],
#   ['1円パチンコサーチTOP', 'div'],
#   ['1円パチンコ設置店', 'div'],
#   ['長崎', 'div'],
#   ['西彼杵郡', 'div'],
#   ['ラッキーランド時津店', 'div'],
#   ['1円パチンコサーチTOP', 'ul'],
#   ['1円パチンコ設置店', 'ul'],
#   ['長崎', 'ul'],
#   ['西彼杵郡', 'ul'],
#   ['ラッキーランド時津店', 'ul'],
#   ['1円パチンコサーチTOP', 'li'],
#   ['1円パチンコサーチTOP', 'a'],
#   ['1円パチンコ設置店', 'li'],
#   ['1円パチンコ設置店', 'a'],
#   ['長崎', 'li'],
#   ['長崎', 'a'],
#   ['西彼杵郡', 'li'],
#   ['西彼杵郡', 'a'],
#   ['ラッキーランド時津店', 'li'],
#   ['ラッキーランド時津店', 'a'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'div'],
#   ['ラッキーランド時津店', 'div'],
#   ['パチンコ', 'div'],
#   ['0.5円', 'div'],
#   ['1円', 'div'],
#   ['2円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['スロット', 'div'],
#   ['2円', 'div'],
#   ['5円', 'div'],
#   ['10円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['換金率(交換率)', 'div'],
#   ['備考', 'div'],
#   ['関連リンク', 'div'],
#   ['口コミを投稿する', 'div'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'div'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'div'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'div'],
#   ['お名前', 'div'],
#   ['口コミ本文', 'div'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'div'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'div'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。', 'div'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'div'],
#   ['是非、ご利用ください。', 'div'],
#   ['1円パチンコサーチ携帯版', 'div'],
#   ['http://1pachi-search.com/mobile/', 'div'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'div'],
#   ['西彼杵郡一覧へ', 'div'],
#   ['長崎 エリア', 'div'],
#   ['エリア一覧', 'div'],
#   ['長崎市', 'div'],
#   ['佐世保市', 'div'],
#   ['島原市', 'div'],
#   ['諌早市', 'div'],
#   ['大村市', 'div'],
#   ['松浦市', 'div'],
#   ['対馬市', 'div'],
#   ['壱岐市', 'div'],
#   ['五島市', 'div'],
#   ['西海市', 'div'],
#   ['雲仙市', 'div'],
#   ['南島原市', 'div'],
#   ['西彼杵郡', 'div'],
#   ['東彼杵郡', 'div'],
#   ['北松浦郡', 'div'],
#   ['南松浦郡', 'div'],
#   ['都道府県選択へ', 'div'],
#   ['新規店舗登録', 'div'],
#   ['■AD', 'div'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'article'],
#   ['ラッキーランド時津店', 'article'],
#   ['パチンコ', 'article'],
#   ['0.5円', 'article'],
#   ['1円', 'article'],
#   ['2円', 'article'],
#   ['-', 'article'],
#   ['-', 'article'],
#   ['○', 'article'],
#   ['スロット', 'article'],
#   ['2円', 'article'],
#   ['5円', 'article'],
#   ['10円', 'article'],
#   ['-', 'article'],
#   ['-', 'article'],
#   ['○', 'article'],
#   ['換金率(交換率)', 'article'],
#   ['備考', 'article'],
#   ['関連リンク', 'article'],
#   ['口コミを投稿する', 'article'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'article'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'article'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'article'],
#   ['お名前', 'article'],
#   ['口コミ本文', 'article'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'article'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'article'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。',
#    'article'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'article'],
#   ['是非、ご利用ください。', 'article'],
#   ['1円パチンコサーチ携帯版', 'article'],
#   ['http://1pachi-search.com/mobile/', 'article'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'article'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'div'],
#   ['ラッキーランド時津店', 'div'],
#   ['パチンコ', 'div'],
#   ['0.5円', 'div'],
#   ['1円', 'div'],
#   ['2円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['スロット', 'div'],
#   ['2円', 'div'],
#   ['5円', 'div'],
#   ['10円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['換金率(交換率)', 'div'],
#   ['備考', 'div'],
#   ['関連リンク', 'div'],
#   ['口コミを投稿する', 'div'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'div'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'div'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'div'],
#   ['お名前', 'div'],
#   ['口コミ本文', 'div'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'div'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'div'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。', 'div'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'div'],
#   ['是非、ご利用ください。', 'div'],
#   ['1円パチンコサーチ携帯版', 'div'],
#   ['http://1pachi-search.com/mobile/', 'div'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'div'],
#   ['1円パチンコ 5円スロット 設置店・換金率', 'h1'],
#   ['ラッキーランド時津店', 'section'],
#   ['パチンコ', 'section'],
#   ['0.5円', 'section'],
#   ['1円', 'section'],
#   ['2円', 'section'],
#   ['-', 'section'],
#   ['-', 'section'],
#   ['○', 'section'],
#   ['スロット', 'section'],
#   ['2円', 'section'],
#   ['5円', 'section'],
#   ['10円', 'section'],
#   ['-', 'section'],
#   ['-', 'section'],
#   ['○', 'section'],
#   ['換金率(交換率)', 'section'],
#   ['備考', 'section'],
#   ['関連リンク', 'section'],
#   ['口コミを投稿する', 'section'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'section'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'section'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'section'],
#   ['お名前', 'section'],
#   ['口コミ本文', 'section'],
#   ['ラッキーランド時津店', 'h1'],
#   ['パチンコ', 'table'],
#   ['0.5円', 'table'],
#   ['1円', 'table'],
#   ['2円', 'table'],
#   ['-', 'table'],
#   ['-', 'table'],
#   ['○', 'table'],
#   ['スロット', 'table'],
#   ['2円', 'table'],
#   ['5円', 'table'],
#   ['10円', 'table'],
#   ['-', 'table'],
#   ['-', 'table'],
#   ['○', 'table'],
#   ['換金率(交換率)', 'table'],
#   ['備考', 'table'],
#   ['パチンコ', 'tbody'],
#   ['0.5円', 'tbody'],
#   ['1円', 'tbody'],
#   ['2円', 'tbody'],
#   ['-', 'tbody'],
#   ['-', 'tbody'],
#   ['○', 'tbody'],
#   ['スロット', 'tbody'],
#   ['2円', 'tbody'],
#   ['5円', 'tbody'],
#   ['10円', 'tbody'],
#   ['-', 'tbody'],
#   ['-', 'tbody'],
#   ['○', 'tbody'],
#   ['換金率(交換率)', 'tbody'],
#   ['備考', 'tbody'],
#   ['パチンコ', 'tr'],
#   ['0.5円', 'tr'],
#   ['1円', 'tr'],
#   ['2円', 'tr'],
#   ['-', 'tr'],
#   ['-', 'tr'],
#   ['○', 'tr'],
#   ['スロット', 'tr'],
#   ['2円', 'tr'],
#   ['5円', 'tr'],
#   ['10円', 'tr'],
#   ['-', 'tr'],
#   ['-', 'tr'],
#   ['○', 'tr'],
#   ['パチンコ', 'th'],
#   ['0.5円', 'td'],
#   ['1円', 'td'],
#   ['2円', 'td'],
#   ['-', 'td'],
#   ['-', 'td'],
#   ['○', 'td'],
#   ['0.5円', 'div'],
#   ['1円', 'div'],
#   ['2円', 'div'],
#   ['0.5円', 'div'],
#   ['1円', 'div'],
#   ['2円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['-', 'p'],
#   ['-', 'p'],
#   ['○', 'p'],
#   ['スロット', 'th'],
#   ['2円', 'td'],
#   ['5円', 'td'],
#   ['10円', 'td'],
#   ['-', 'td'],
#   ['-', 'td'],
#   ['○', 'td'],
#   ['2円', 'div'],
#   ['5円', 'div'],
#   ['10円', 'div'],
#   ['2円', 'div'],
#   ['5円', 'div'],
#   ['10円', 'div'],
#   ['-', 'div'],
#   ['-', 'div'],
#   ['○', 'div'],
#   ['-', 'p'],
#   ['-', 'p'],
#   ['○', 'p'],
#   ['換金率(交換率)', 'tr'],
#   ['備考', 'tr'],
#   ['換金率(交換率)', 'th'],
#   ['備考', 'th'],
#   ['関連リンク', 'table'],
#   ['関連リンク', 'tbody'],
#   ['関連リンク', 'tr'],
#   ['関連リンク', 'th'],
#   ['口コミを投稿する', 'h2'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'div'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'div'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'div'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'ul'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'ul'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'ul'],
#   ['口コミは承認制となっております。承認には多少お時間を頂きます。', 'li'],
#   ['口コミ機能は利用規約を承諾した後にご利用ください。', 'li'],
#   ['当サイトの判断によりコメントを予告なく削除する場合がございます。', 'li'],
#   ['お名前', 'div'],
#   ['口コミ本文', 'div'],
#   ['お名前', 'form'],
#   ['口コミ本文', 'form'],
#   ['お名前', 'input'],
#   ['口コミ本文', 'input'],
#   ['お名前', 'input'],
#   ['口コミ本文', 'input'],
#   ['お名前', 'input'],
#   ['口コミ本文', 'input'],
#   ['お名前', 'input'],
#   ['口コミ本文', 'input'],
#   ['お名前', 'div'],
#   ['お名前', 'label'],
#   ['口コミ本文', 'label'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'section'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'section'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。',
#    'section'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'section'],
#   ['是非、ご利用ください。', 'section'],
#   ['1円パチンコサーチ携帯版', 'section'],
#   ['http://1pachi-search.com/mobile/', 'section'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'section'],
#   ['1円パチンコサーチのフィーチャーフォンサイト', 'div'],
#   ['1円パチンコサーチにはフィーチャーフォン向け携帯サイトがあります。', 'div'],
#   ['買物中に打ちたくなった、出張からの帰り道に一息など、出先で携帯から2円パチンコ、10円スロットなどを設置店舗検索ができます。', 'div'],
#   ['コンテンツはPC版1パチサーチとほぼ同一コンテンツになりますので、外出中に見つけたニコスロ、ニコパチや遊パチ、遊スロなどの低資金遊戯台情報をリアルタイムで確認可能となっております。',
#    'div'],
#   ['是非、ご利用ください。', 'div'],
#   ['1円パチンコサーチ携帯版', 'div'],
#   ['http://1pachi-search.com/mobile/', 'div'],
#   ['＃スマートフォンからはPCサイトと同じURLより閲覧可能です。', 'div'],
#   ['西彼杵郡一覧へ', 'aside'],
#   ['長崎 エリア', 'aside'],
#   ['エリア一覧', 'aside'],
#   ['長崎市', 'aside'],
#   ['佐世保市', 'aside'],
#   ['島原市', 'aside'],
#   ['諌早市', 'aside'],
#   ['大村市', 'aside'],
#   ['松浦市', 'aside'],
#   ['対馬市', 'aside'],
#   ['壱岐市', 'aside'],
#   ['五島市', 'aside'],
#   ['西海市', 'aside'],
#   ['雲仙市', 'aside'],
#   ['南島原市', 'aside'],
#   ['西彼杵郡', 'aside'],
#   ['東彼杵郡', 'aside'],
#   ['北松浦郡', 'aside'],
#   ['南松浦郡', 'aside'],
#   ['都道府県選択へ', 'aside'],
#   ['新規店舗登録', 'aside'],
#   ['■AD', 'aside'],
#   ['西彼杵郡一覧へ', 'a'],
#   ['長崎 エリア', 'nav'],
#   ['エリア一覧', 'nav'],
#   ['長崎市', 'nav'],
#   ['佐世保市', 'nav'],
#   ['島原市', 'nav'],
#   ['諌早市', 'nav'],
#   ['大村市', 'nav'],
#   ['松浦市', 'nav'],
#   ['対馬市', 'nav'],
#   ['壱岐市', 'nav'],
#   ['五島市', 'nav'],
#   ['西海市', 'nav'],
#   ['雲仙市', 'nav'],
#   ['南島原市', 'nav'],
#   ['西彼杵郡', 'nav'],
#   ['東彼杵郡', 'nav'],
#   ['北松浦郡', 'nav'],
#   ['南松浦郡', 'nav'],
#   ['長崎 エリア', 'h1'],
#   ['エリア一覧', 'div'],
#   ['長崎市', 'div'],
#   ['佐世保市', 'div'],
#   ['島原市', 'div'],
#   ['諌早市', 'div'],
#   ['大村市', 'div'],
#   ['松浦市', 'div'],
#   ['対馬市', 'div'],
#   ['壱岐市', 'div'],
#   ['五島市', 'div'],
#   ['西海市', 'div'],
#   ['雲仙市', 'div'],
#   ['南島原市', 'div'],
#   ['西彼杵郡', 'div'],
#   ['東彼杵郡', 'div'],
#   ['北松浦郡', 'div'],
#   ['南松浦郡', 'div'],
#   ['エリア一覧', 'h2'],
#   ['長崎市', 'ul'],
#   ['佐世保市', 'ul'],
#   ['島原市', 'ul'],
#   ['諌早市', 'ul'],
#   ['大村市', 'ul'],
#   ['松浦市', 'ul'],
#   ['対馬市', 'ul'],
#   ['壱岐市', 'ul'],
#   ['五島市', 'ul'],
#   ['西海市', 'ul'],
#   ['雲仙市', 'ul'],
#   ['南島原市', 'ul'],
#   ['西彼杵郡', 'ul'],
#   ['東彼杵郡', 'ul'],
#   ['北松浦郡', 'ul'],
#   ['南松浦郡', 'ul'],
#   ['長崎市', 'li'],
#   ['長崎市', 'a'],
#   ['佐世保市', 'li'],
#   ['佐世保市', 'a'],
#   ['島原市', 'li'],
#   ['島原市', 'a'],
#   ['諌早市', 'li'],
#   ['諌早市', 'a'],
#   ['大村市', 'li'],
#   ['大村市', 'a'],
#   ['松浦市', 'li'],
#   ['松浦市', 'a'],
#   ['対馬市', 'li'],
#   ['対馬市', 'a'],
#   ['壱岐市', 'li'],
#   ['壱岐市', 'a'],
#   ['五島市', 'li'],
#   ['五島市', 'a'],
#   ['西海市', 'li'],
#   ['西海市', 'a'],
#   ['雲仙市', 'li'],
#   ['雲仙市', 'a'],
#   ['南島原市', 'li'],
#   ['南島原市', 'a'],
#   ['西彼杵郡', 'li'],
#   ['西彼杵郡', 'a'],
#   ['東彼杵郡', 'li'],
#   ['東彼杵郡', 'a'],
#   ['北松浦郡', 'li'],
#   ['北松浦郡', 'a'],
#   ['南松浦郡', 'li'],
#   ['南松浦郡', 'a'],
#   ['都道府県選択へ', 'a'],
#   ['新規店舗登録', 'a'],
#   ['■AD', 'div'],
#   ['おすすめコンテンツ', 'aside'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'aside'],
#   ['ハーデス', 'aside'],
#   ['アプリ配信中', 'aside'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'aside'],
#   ['CRリング アプリ', 'aside'],
#   ['バジリスク絆', 'aside'],
#   ['アプリ配信中', 'aside'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'aside'],
#   ['（端末拡大版）', 'aside'],
#   ['ジャグラーアプリ', 'aside'],
#   ['スロアプリ配信中', 'aside'],
#   ['1円パチンコや5円スロットをホールで実践する前に、アプリやメーカー公認サイトなどでシミュレーションしてみてはいかがでしょうか。', 'aside'],
#   ['1円パチンコであれば普段ホールで打てないような釘状態での遊戯体験や、5円スロットであればなかなかお目にかかれない設定6での実践体験が可能です！',
#    'aside'],
#   ['実際にホールで遊戯した後に実践の復習として使ってみても良いかもしれません。', 'aside'],
#   ['ツイート', 'aside'],
#   ['おすすめコンテンツ', 'div'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'ul'],
#   ['ハーデス', 'ul'],
#   ['アプリ配信中', 'ul'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'ul'],
#   ['CRリング アプリ', 'ul'],
#   ['バジリスク絆', 'ul'],
#   ['アプリ配信中', 'ul'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'ul'],
#   ['（端末拡大版）', 'ul'],
#   ['ジャグラーアプリ', 'ul'],
#   ['スロアプリ配信中', 'ul'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'li'],
#   ['ぱちんこAKB48アプリ絶賛配信中!!', 'a'],
#   ['ハーデス', 'li'],
#   ['アプリ配信中', 'li'],
#   ['ハーデス', 'a'],
#   ['アプリ配信中', 'a'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'li'],
#   ['｢パーラーサンセイ｣OPEN!牙狼FINALをプレイ', 'a'],
#   ['CRリング アプリ', 'li'],
#   ['CRリング アプリ', 'a'],
#   ['バジリスク絆', 'li'],
#   ['アプリ配信中', 'li'],
#   ['バジリスク絆', 'a'],
#   ['アプリ配信中', 'a'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'li'],
#   ['（端末拡大版）', 'li'],
#   ['【スマートフォン用】北斗の拳\u3000転生の章', 'a'],
#   ['（端末拡大版）', 'a'],
#   ['ジャグラーアプリ', 'li'],
#   ['スロアプリ配信中', 'li'],
#   ['ジャグラーアプリ', 'a'],
#   ['スロアプリ配信中', 'a'],
#   ['1円パチンコや5円スロットをホールで実践する前に、アプリやメーカー公認サイトなどでシミュレーションしてみてはいかがでしょうか。', 'div'],
#   ['1円パチンコであれば普段ホールで打てないような釘状態での遊戯体験や、5円スロットであればなかなかお目にかかれない設定6での実践体験が可能です！',
#    'div'],
#   ['実際にホールで遊戯した後に実践の復習として使ってみても良いかもしれません。', 'div'],
#   ['1円パチンコや5円スロットをホールで実践する前に、アプリやメーカー公認サイトなどでシミュレーションしてみてはいかがでしょうか。', 'div'],
#   ['1円パチンコであれば普段ホールで打てないような釘状態での遊戯体験や、5円スロットであればなかなかお目にかかれない設定6での実践体験が可能です！',
#    'div'],
#   ['実際にホールで遊戯した後に実践の復習として使ってみても良いかもしれません。', 'div'],
#   ['ツイート', 'div'],
#   ['ツイート', 'div'],
#   ['ツイート', 'a'],
#   ['利用規約', 'footer'],
#   ['｜', 'footer'],
#   ['リンク', 'footer'],
#   ['｜', 'footer'],
#   ['お問い合わせ', 'footer'],
#   ['© 2010-2022 1円パチンコサーチ All rights reserved.', 'footer'],
#   ['利用規約', 'div'],
#   ['｜', 'div'],
#   ['リンク', 'div'],
#   ['｜', 'div'],
#   ['お問い合わせ', 'div'],
#   ['© 2010-2022 1円パチンコサーチ All rights reserved.', 'div'],
#   ['利用規約', 'div'],
#   ['｜', 'div'],
#   ['リンク', 'div'],
#   ['｜', 'div'],
#   ['お問い合わせ', 'div'],
#   ['利用規約', 'a'],
#   ['リンク', 'a'],
#   ['お問い合わせ', 'a'],
#   ['© 2010-2022 1円パチンコサーチ All rights reserved.', 'div'],
#   ['TOP', 'p'],
#   ['TOP', 'a'],
#   ['TOP', 'span']]}

# %%
"""
from bunkai import Bunkai
bunkai = Bunkai()
def parse_lines_bunkai(lines):
    lines = lines.strip().replace("\n", "\u2581")
    return bunkai("".join(lines))

"""
# Out:
# '\nfrom bunkai import Bunkai\nbunkai = Bunkai()\ndef parse_lines_bunkai(lines):\n    lines = lines.strip().replace("\n", "▁")\n    return bunkai("".join(lines))\n\n'

# %%
from src.cleaner.auto_filter import do_filter
from src.cleaner import text_normalizer
from src.cleaner.junk_filter import remove_junk_lines
lines=data_loaded[23]["text"]
lines=[i[0] for i in lines]
#lines=remove_junk_lines(lines)
text="\n".join(lines)

# %%
import functools
from ja_sentence_segmenter.common.pipeline import make_pipeline
from ja_sentence_segmenter.concatenate.simple_concatenator import concatenate_matching
from ja_sentence_segmenter.normalize.neologd_normalizer import normalize
from ja_sentence_segmenter.split.simple_splitter import split_newline, split_punctuation

split_punc2 = functools.partial(split_punctuation, punctuations=r"。!?")
concat_tail_te = functools.partial(concatenate_matching, former_matching_rule=r"^(?P<result>.+)(て)$", remove_former_matched=False)
segmenter = make_pipeline(normalize, split_newline, concat_tail_te, split_punc2)
lines=list(segmenter(lines))

# %%
lines
# Out:
# ['URLからファイルシステム上の位置へのマップ-Apache HTTPサーババージョン2.4モジュール|ディレクティブ|FAQ|用語|サイトマップApache HTTPサーババージョン2.4Apache>HTTPサーバ>ドキュメンテーション>バージョン2.4URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。',
#  '最近更新された内容を見るには英語版をご覧下さい。',
#  'この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。',
#  '関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。',
#  'ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。',
#  'Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。',
#  'この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。',
#  'また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。',
#  'DocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。',
#  'Apacheはこのために複数の方法を用意しています。',
#  'Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。',
#  'セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。',
#  '代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。',
#  'たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。',
#  'ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。',
#  'もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。',
#  'たとえば、ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/～user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。',
#  'ユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを～user/として参照できます。',
#  'mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。',
#  'http://www.example.com/～user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。',
#  'ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。',
#  'デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。',
#  'ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。',
#  'Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。',
#  '中にはシンボル "～" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。',
#  'mod_userdirはこの機能をサポートしていません。',
#  'しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。',
#  'たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。',
#  'ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。',
#  'これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。',
#  'たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。',
#  'サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。',
#  'Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。',
#  'たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。',
#  'この手法はリバースプロキシと呼ばれています。',
#  'ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。',
#  'クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。',
#  '次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。',
#  'ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPassディレクティブはサーバが適切なドキュメントを取得するように設定し、ProxyPassReverseディレクティブはinternal.example.comからのリダイレクトがローカルサーバの適切なディレクトリを指すように書き換えます。',
#  '同様にProxyPassReverseCookieDomainとProxyPassReverseCookiePathでバックエンド側サーバの発行したCookieを書き換えることができます。',
#  'ただし、ドキュメントの中のリンクは書き換えられない、ということは知っておいてください。',
#  'ですから、internal.example.comへの絶対パスによるリンクでは、クライアントがプロキシサーバを抜け出してinternal.example.comに直接リクエストを送る、ということになります。',
#  'サードパーティ製モジュールのmod_proxy_htmlは、HTMLとXHTML中のリンクを書き換えることができます。',
#  'リライトエンジンより一層強力な置換が必要なときは、mod_rewriteが提供するリライトエンジンが役に立つでしょう。',
#  'このモジュールにより提供されるディレクティブはブラウザの種類、リクエスト元のIPアドレスなどのリクエストの特徴を使って送り返すコンテンツの場所を決めます。',
#  'さらに、mod_rewriteは外部のデータベースファイルやプログラムを使ってリクエストの扱い方を決めることもできます。',
#  'リライトエンジンは上で挙げられている三つのマッピングすべてを行なうことができます:内部のリダイレクト(エイリアス)、外部のリダイレクト、プロキシです。',
#  'mod_rewriteを使う多くの実用的な例はURLリライトガイドで説明されています。',
#  'File Not Found必ず、リクエストされたURLに対応するファイルがファイルシステムに無いという場合が発生します。',
#  'これが起こるのにはいくつかの理由があります。',
#  '場合によっては、ドキュメントを別の場所に移動した結果であることがあります。',
#  'この場合は、クライアントにリソースの新しい位置を知らせるためにURLリダイレクションを使うのが最善の方法です。',
#  'そうすることによって、リソースは新しい位置に移動しているけれども、古いブックマークやリンクが動作し続けるようにすることができます。',
#  '"File Not Found" エラーのもう一つのよくある理由は、ブラウザへの直接入力やHTMLリンクからの偶発的なURLの入力間違いです。',
#  'Apacheはこの問題を改善するために、mod_spelingモジュール(意図的な綴り間違い)(訳注:正しくはspelling)を提供しています。',
#  'このモジュールが使用されているときは、"File Not Found" エラーを横取りして、似たファイル名のリソースを探します。',
#  'もし一つだけ見つかった場合はmod_spelingはクライアントに正しい位置を知らせるためにHTTPリダイレクトを送ります。',
#  'もし複数の「近い」ファイルが見つかった場合は、それら代替となりえるもののリストがクライアントに表示されます。',
#  'mod_spelingの非常に有用な機能は、大文字小文字を区別せずにファイル名を比較するものです。',
#  'これはURLとunixのファイルシステムが両方とも大文字小文字を区別するものである、ということをユーザが知らないシステムで役に立ちます。',
#  'ただし、時折のURL訂正程度で済まず、mod_spelingをより多く使用すると、サーバにさらなる負荷がかかります。',
#  'すべての「正しくない」リクエストの後にURLのリダイレクトとクライアントからの新しいリクエストがくることになりますから。',
#  'コンテンツの位置を決めようとするすべての試みが失敗すると、Apacheは、HTTPステータスコード404(file not found)と共にエラーページを返します。',
#  'このエラーページの外観はErrorDocumentディレクティブで制御され、カスタムエラーレスポンスで説明されているように、柔軟な設定を行なうことができます。',
#  '翻訳済み言語:en|fr|ja|ko|trコメントNotice:This is not a Q&A section.Comments placed here should be pointed towards suggestions on improving the documentation or server,and may be removed again by our moderators if they are either implemented or considered invalid/off-topic.Questions on how to manage the Apache HTTP Server should be directed at either our IRC channel,#httpd,on Freenode,or sent to ourmailing lists.Copyright 2019 The Apache Software Foundation.この文書はApache License,Version 2.0のライセンスで提供されています。',
#  '.モジュール|ディレクティブ|FAQ|用語|サイトマップURLからファイルシステム上の位置へのマップ-Apache HTTPサーババージョン2.4URLからファイルシステム上の位置へのマップ-Apache HTTPサーババージョン2.4モジュール|ディレクティブ|FAQ|用語|サイトマップApache HTTPサーババージョン2.4Apache>HTTPサーバ>ドキュメンテーション>バージョン2.4URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。',
#  '最近更新された内容を見るには英語版をご覧下さい。',
#  'この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。',
#  '関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。',
#  'ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。',
#  'Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。',
#  'この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。',
#  'また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。',
#  'DocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。',
#  'Apacheはこのために複数の方法を用意しています。',
#  'Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。',
#  'セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。',
#  '代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。',
#  'たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。',
#  'ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。',
#  'もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。',
#  'たとえば、ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/～user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。',
#  'ユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを～user/として参照できます。',
#  'mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。',
#  'http://www.example.com/～user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。',
#  'ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。',
#  'デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。',
#  'ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。',
#  'Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。',
#  '中にはシンボル "～" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。',
#  'mod_userdirはこの機能をサポートしていません。',
#  'しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。',
#  'たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。',
#  'ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。',
#  'これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。',
#  'たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。',
#  'サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。',
#  'Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。',
#  'たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。',
#  'この手法はリバースプロキシと呼ばれています。',
#  'ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。',
#  'クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。',
#  '次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。',
#  'ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPassディレクティブはサーバが適切なドキュメントを取得するように設定し、ProxyPassReverseディレクティブはinternal.example.comからのリダイレクトがローカルサーバの適切なディレクトリを指すように書き換えます。',
#  '同様にProxyPassReverseCookieDomainとProxyPassReverseCookiePathでバックエンド側サーバの発行したCookieを書き換えることができます。',
#  'ただし、ドキュメントの中のリンクは書き換えられない、ということは知っておいてください。',
#  'ですから、internal.example.comへの絶対パスによるリンクでは、クライアントがプロキシサーバを抜け出してinternal.example.comに直接リクエストを送る、ということになります。',
#  'サードパーティ製モジュールのmod_proxy_htmlは、HTMLとXHTML中のリンクを書き換えることができます。',
#  'リライトエンジンより一層強力な置換が必要なときは、mod_rewriteが提供するリライトエンジンが役に立つでしょう。',
#  'このモジュールにより提供されるディレクティブはブラウザの種類、リクエスト元のIPアドレスなどのリクエストの特徴を使って送り返すコンテンツの場所を決めます。',
#  'さらに、mod_rewriteは外部のデータベースファイルやプログラムを使ってリクエストの扱い方を決めることもできます。',
#  'リライトエンジンは上で挙げられている三つのマッピングすべてを行なうことができます:内部のリダイレクト(エイリアス)、外部のリダイレクト、プロキシです。',
#  'mod_rewriteを使う多くの実用的な例はURLリライトガイドで説明されています。',
#  'File Not Found必ず、リクエストされたURLに対応するファイルがファイルシステムに無いという場合が発生します。',
#  'これが起こるのにはいくつかの理由があります。',
#  '場合によっては、ドキュメントを別の場所に移動した結果であることがあります。',
#  'この場合は、クライアントにリソースの新しい位置を知らせるためにURLリダイレクションを使うのが最善の方法です。',
#  'そうすることによって、リソースは新しい位置に移動しているけれども、古いブックマークやリンクが動作し続けるようにすることができます。',
#  '"File Not Found" エラーのもう一つのよくある理由は、ブラウザへの直接入力やHTMLリンクからの偶発的なURLの入力間違いです。',
#  'Apacheはこの問題を改善するために、mod_spelingモジュール(意図的な綴り間違い)(訳注:正しくはspelling)を提供しています。',
#  'このモジュールが使用されているときは、"File Not Found" エラーを横取りして、似たファイル名のリソースを探します。',
#  'もし一つだけ見つかった場合はmod_spelingはクライアントに正しい位置を知らせるためにHTTPリダイレクトを送ります。',
#  'もし複数の「近い」ファイルが見つかった場合は、それら代替となりえるもののリストがクライアントに表示されます。',
#  'mod_spelingの非常に有用な機能は、大文字小文字を区別せずにファイル名を比較するものです。',
#  'これはURLとunixのファイルシステムが両方とも大文字小文字を区別するものである、ということをユーザが知らないシステムで役に立ちます。',
#  'ただし、時折のURL訂正程度で済まず、mod_spelingをより多く使用すると、サーバにさらなる負荷がかかります。',
#  'すべての「正しくない」リクエストの後にURLのリダイレクトとクライアントからの新しいリクエストがくることになりますから。',
#  'コンテンツの位置を決めようとするすべての試みが失敗すると、Apacheは、HTTPステータスコード404(file not found)と共にエラーページを返します。',
#  'このエラーページの外観はErrorDocumentディレクティブで制御され、カスタムエラーレスポンスで説明されているように、柔軟な設定を行なうことができます。',
#  '翻訳済み言語:en|fr|ja|ko|trコメントNotice:This is not a Q&A section.Comments placed here should be pointed towards suggestions on improving the documentation or server,and may be removed again by our moderators if they are either implemented or considered invalid/off-topic.Questions on how to manage the Apache HTTP Server should be directed at either our IRC channel,#httpd,on Freenode,or sent to ourmailing lists.Copyright 2019 The Apache Software Foundation.この文書はApache License,Version 2.0のライセンスで提供されています。',
#  '.モジュール|ディレクティブ|FAQ|用語|サイトマップモジュール|ディレクティブ|FAQ|用語|サイトマップApache HTTPサーババージョン2.4モジュール|ディレクティブ|FAQ|用語|サイトマップモジュールディレクティブFAQ用語サイトマップApache HTTPサーババージョン2.4Apache>HTTPサーバ>ドキュメンテーション>バージョン2.4ApacheHTTPサーバドキュメンテーションバージョン2.4URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。',
#  '最近更新された内容を見るには英語版をご覧下さい。',
#  'この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。',
#  '関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。',
#  'ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。',
#  'Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。',
#  'この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。',
#  'また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。',
#  'DocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。',
#  'Apacheはこのために複数の方法を用意しています。',
#  'Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。',
#  'セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。',
#  '代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。',
#  'たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。',
#  'ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。',
#  'もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。',
#  'たとえば、ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/～user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。',
#  'ユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを～user/として参照できます。',
#  'mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。',
#  'http://www.example.com/～user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。',
#  'ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。',
#  'デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。',
#  'ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。',
#  'Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。',
#  '中にはシンボル "～" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。',
#  'mod_userdirはこの機能をサポートしていません。',
#  'しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。',
#  'たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。',
#  'ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。',
#  'これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。',
#  'たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。',
#  'サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。',
#  'Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。',
#  'たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。',
#  'この手法はリバースプロキシと呼ばれています。',
#  'ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。',
#  'クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。',
#  '次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。',
#  'ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPassディレクティブはサーバが適切なドキュメントを取得するように設定し、ProxyPassReverseディレクティブはinternal.example.comからのリダイレクトがローカルサーバの適切なディレクトリを指すように書き換えます。',
#  '同様にProxyPassReverseCookieDomainとProxyPassReverseCookiePathでバックエンド側サーバの発行したCookieを書き換えることができます。',
#  'ただし、ドキュメントの中のリンクは書き換えられない、ということは知っておいてください。',
#  'ですから、internal.example.comへの絶対パスによるリンクでは、クライアントがプロキシサーバを抜け出してinternal.example.comに直接リクエストを送る、ということになります。',
#  'サードパーティ製モジュールのmod_proxy_htmlは、HTMLとXHTML中のリンクを書き換えることができます。',
#  'リライトエンジンより一層強力な置換が必要なときは、mod_rewriteが提供するリライトエンジンが役に立つでしょう。',
#  'このモジュールにより提供されるディレクティブはブラウザの種類、リクエスト元のIPアドレスなどのリクエストの特徴を使って送り返すコンテンツの場所を決めます。',
#  'さらに、mod_rewriteは外部のデータベースファイルやプログラムを使ってリクエストの扱い方を決めることもできます。',
#  'リライトエンジンは上で挙げられている三つのマッピングすべてを行なうことができます:内部のリダイレクト(エイリアス)、外部のリダイレクト、プロキシです。',
#  'mod_rewriteを使う多くの実用的な例はURLリライトガイドで説明されています。',
#  'File Not Found必ず、リクエストされたURLに対応するファイルがファイルシステムに無いという場合が発生します。',
#  'これが起こるのにはいくつかの理由があります。',
#  '場合によっては、ドキュメントを別の場所に移動した結果であることがあります。',
#  'この場合は、クライアントにリソースの新しい位置を知らせるためにURLリダイレクションを使うのが最善の方法です。',
#  'そうすることによって、リソースは新しい位置に移動しているけれども、古いブックマークやリンクが動作し続けるようにすることができます。',
#  '"File Not Found" エラーのもう一つのよくある理由は、ブラウザへの直接入力やHTMLリンクからの偶発的なURLの入力間違いです。',
#  'Apacheはこの問題を改善するために、mod_spelingモジュール(意図的な綴り間違い)(訳注:正しくはspelling)を提供しています。',
#  'このモジュールが使用されているときは、"File Not Found" エラーを横取りして、似たファイル名のリソースを探します。',
#  'もし一つだけ見つかった場合はmod_spelingはクライアントに正しい位置を知らせるためにHTTPリダイレクトを送ります。',
#  'もし複数の「近い」ファイルが見つかった場合は、それら代替となりえるもののリストがクライアントに表示されます。',
#  'mod_spelingの非常に有用な機能は、大文字小文字を区別せずにファイル名を比較するものです。',
#  'これはURLとunixのファイルシステムが両方とも大文字小文字を区別するものである、ということをユーザが知らないシステムで役に立ちます。',
#  'ただし、時折のURL訂正程度で済まず、mod_spelingをより多く使用すると、サーバにさらなる負荷がかかります。',
#  'すべての「正しくない」リクエストの後にURLのリダイレクトとクライアントからの新しいリクエストがくることになりますから。',
#  'コンテンツの位置を決めようとするすべての試みが失敗すると、Apacheは、HTTPステータスコード404(file not found)と共にエラーページを返します。',
#  'このエラーページの外観はErrorDocumentディレクティブで制御され、カスタムエラーレスポンスで説明されているように、柔軟な設定を行なうことができます。',
#  'URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。',
#  '最近更新された内容を見るには英語版をご覧下さい。',
#  'この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。',
#  'URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|tr翻訳済み言語:en|fr|ja|ko|tr翻訳済み言語:enfrjakotrこの日本語訳はすでに古くなっている可能性があります。',
#  '最近更新された内容を見るには英語版をご覧下さい。',
#  'この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。',
#  '関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found関連するモジュールとディレクティブ関連するモジュールとディレクティブDocumentRootDocumentRootDocumentRoot外のファイルDocumentRoot外のファイルユーザディレクトリユーザディレクトリURLリダイレクションURLリダイレクションリバースプロキシリバースプロキシリライトエンジンリライトエンジンFile Not FoundFile Not Found参照コメントコメントコメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDir関連するモジュールとディレクティブ関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDir関連モジュール関連ディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasmod_aliasmod_aliasmod_aliasmod_proxymod_proxymod_proxymod_rewritemod_rewritemod_rewritemod_userdirmod_userdirmod_userdirmod_spelingmod_spelingmod_spelingmod_vhost_aliasmod_vhost_aliasmod_vhost_...リクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。',
#  'ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。',
#  'Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。',
#  'この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。',
#  'また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。',
#  'DocumentRootDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。',
#  'ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。',
#  'DocumentRootDocumentRootDocumentRootDocumentRootApacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。',
#  'この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。',
#  'また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。',
#  'バーチャルホストDocumentRootDocumentRootmod_vhost_aliasmod_vhost_aliasDocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。',
#  'Apacheはこのために複数の方法を用意しています。',
#  'Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。',
#  'セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。',
#  '代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。',
#  'たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。',
#  'ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。',
#  'もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。',
#  'たとえば、ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/～user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。',
#  'DocumentRoot外のファイルDocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。',
#  'Apacheはこのために複数の方法を用意しています。',
#  'Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。',
#  'セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。',
#  'DocumentRootDocumentRootDocumentRootDocumentRootOptionsOptionsFollowSymLinksSymLinksIfOwnerMatch代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。',
#  'たとえば、AliasAliasAlias/docs/var/webAlias/docs/var/webAlias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。',
#  'ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。',
#  'http://www.example.com/docs/dir/file.html/var/web/dir/file.htmlScriptAliasScriptAliasもっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。',
#  'たとえば、AliasMatchAliasMatchScriptAliasMatchScriptAliasMatchScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2ScriptAliasMatch^/～([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/～user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。',
#  'http://example.com/～user/cgi-bin/script.cgi/home/user/cgi-bin/script.cgiユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを～user/として参照できます。',
#  'mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。',
#  'http://www.example.com/～user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。',
#  'ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。',
#  'デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。',
#  'ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。',
#  'Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。',
#  '中にはシンボル "～" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。',
#  'mod_userdirはこの機能をサポートしていません。',
#  'しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。',
#  'たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2ユーザディレクトリユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを～user/として参照できます。',
#  'mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。',
#  'user～user/mod_userdirmod_userdirhttp://www.example.com/～user/file.htmlhttp://www.example.com/～user/file.htmlhttp://www.example.com/～user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。',
#  'ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。',
#  'デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。',
#  'ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。',
#  'UserDirUserDirUserdir public_html/home/user/public_html/file.html/home/user//etc/passwdUserdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。',
#  'UserdirUserdir/etc/passwd中にはシンボル "～" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。',
#  'mod_userdirはこの機能をサポートしていません。',
#  'しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。',
#  'たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:%7eAliasMatchAliasMatchhttp://www.example.com/upages/user/file.html/home/user/public_html/file.htmlAliasMatchAliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2AliasMatch^/upages/([a-zA-Z0-9]+)/?',
#  '(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。',
#  'ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。',
#  'これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。',
#  'たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。',
#  'サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。',
#  'Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。',
#  'たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlURLリダイレクションURLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。',
#  'ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。',
#  'これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。',
#  'たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:リダイレクションRedirectRedirectDocumentRootDocumentRoot/foo//bar/Redirect permanent/foo/http://www.example.com/bar/Redirect permanent/foo/http://www.example.com/bar/Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。',
#  'サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。',
#  '/foo/www.example.com/bar//foo/Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。',
#  'たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatchRedirectMatchRedirectMatch permanent^/$http://www.example.com/startpage.htmlRedirectMatch permanent^/$http://www.example.com/startpage.htmlRedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlRedirectMatch temp.*http://othersite.example.com/startpage.htmlRedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。',
#  'この手法はリバースプロキシと呼ばれています。',
#  'ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。',
#  'クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。',
#  '次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。',
#  'ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPassディレクティブはサーバが適切なドキュメントを取得するように設定し、ProxyPassReverseディレクティブはinternal.example.comからのリダイレクトがローカルサーバの適切なディレクトリを指すように書き換えます。',
#  '同様にProxyPassReverseCookieDomainとProxyPassReverseCookiePathでバックエンド側サーバの発行したCookieを書き換えることができます。',
#  'ただし、ドキュメントの中のリンクは書き換えられない、ということは知っておいてください。',
#  'ですから、internal.example.comへの絶対パスによるリンクでは、クライアントがプロキシサーバを抜け出してinternal.example.comに直接リクエストを送る、ということになります。',
#  'サードパーティ製モジュールのmod_proxy_htmlは、HTMLとXHTML中のリンクを書き換えることができます。',
#  'リバースプロキシリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。',
#  'この手法はリバースプロキシと呼ばれています。',
#  'ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。',
#  'クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。',
#  'リバースプロキシ次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。',
#  '/foo/internal.example.com/bar/ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.example.com public.example.comProxyPassReverseCookiePath/foo//bar/ProxyPassディレクティブはサーバが適切なドキュメントを取得するように設定し、ProxyPassReverseディレクティブはinternal.example.comからのリダイレクトがローカルサーバの適切なディレクトリを指すように書き換えます。',
#  '同様にProxyPassReverseCookieDomainとProxyPassReverseCookiePathでバックエンド側サーバの発行したCookieを書き換えることができます。',
#  'ProxyPassProxyPassProxyPassReverseProxyPassReverseinternal.example.comProxyPassReverseCookieDomainProxyPassReverseCookieDomainProxyPassReverseCookiePathProxyPassReverseCookiePathただし、ドキュメントの中のリンクは書き換えられない、ということは知っておいてください。',
#  'ですから、internal.example.comへの絶対パスによるリンクでは、クライアントがプロキシサーバを抜け出してinternal.example.comに直接リクエストを送る、ということになります。',
#  'サードパーティ製モジュールのmod_proxy_htmlは、HTMLとXHTML中のリンクを書き換えることができます。',
#  'internal.example.cominternal.example.commod_proxy_htmlリライトエンジンより一層強力な置換が必要なときは、mod_rewriteが提供するリライトエンジンが役に立つでしょう。',
#  'このモジュールにより提供されるディレクティブはブラウザの種類、リクエスト元のIPアドレスなどのリクエストの特徴を使って送り返すコンテンツの場所を決めます。',
#  'さらに、mod_rewriteは外部のデータベースファイルやプログラムを使ってリクエストの扱い方を決めることもできます。',
#  'リライトエンジンは上で挙げられている三つのマッピングすべてを行なうことができます:内部のリダイレクト(エイリアス)、外部のリダイレクト、プロキシです。',
#  'mod_rewriteを使う多くの実用的な例はURLリライトガイドで説明されています。',
#  'リライトエンジンリライトエンジンより一層強力な置換が必要なときは、mod_rewriteが提供するリライトエンジンが役に立つでしょう。',
#  'このモジュールにより提供されるディレクティブはブラウザの種類、リクエスト元のIPアドレスなどのリクエストの特徴を使って送り返すコンテンツの場所を決めます。',
#  'さらに、mod_rewriteは外部のデータベースファイルやプログラムを使ってリクエストの扱い方を決めることもできます。',
#  'リライトエンジンは上で挙げられている三つのマッピングすべてを行なうことができます:内部のリダイレクト(エイリアス)、外部のリダイレクト、プロキシです。',
#  'mod_rewriteを使う多くの実用的な例はURLリライトガイドで説明されています。',
#  'mod_rewritemod_rewritemod_rewritemod_rewriteURLリライトガイドFile Not Found必ず、リクエストされたURLに対応するファイルがファイルシステムに無いという場合が発生します。',
#  'これが起こるのにはいくつかの理由があります。',
#  '場合によっては、ドキュメントを別の場所に移動した結果であることがあります。',
#  'この場合は、クライアントにリソースの新しい位置を知らせるためにURLリダイレクションを使うのが最善の方法です。',
#  'そうすることによって、リソースは新しい位置に移動しているけれども、古いブックマークやリンクが動作し続けるようにすることができます。',
#  '"File Not Found" エラーのもう一つのよくある理由は、ブラウザへの直接入力やHTMLリンクからの偶発的なURLの入力間違いです。',
#  'Apacheはこの問題を改善するために、mod_spelingモジュール(意図的な綴り間違い)(訳注:正しくはspelling)を提供しています。',
#  'このモジュールが使用されているときは、"File Not Found" エラーを横取りして、似たファイル名のリソースを探します。',
#  'もし一つだけ見つかった場合はmod_spelingはクライアントに正しい位置を知らせるためにHTTPリダイレクトを送ります。',
#  'もし複数の「近い」ファイルが見つかった場合は、それら代替となりえるもののリストがクライアントに表示されます。',
#  'mod_spelingの非常に有用な機能は、大文字小文字を区別せずにファイル名を比較するものです。',
#  'これはURLとunixのファイルシステムが両方とも大文字小文字を区別するものである、ということをユーザが知らないシステムで役に立ちます。',
#  'ただし、時折のURL訂正程度で済まず、mod_spelingをより多く使用すると、サーバにさらなる負荷がかかります。',
#  'すべての「正しくない」リクエストの後にURLのリダイレクトとクライアントからの新しいリクエストがくることになりますから。',
#  'コンテンツの位置を決めようとするすべての試みが失敗すると、Apacheは、HTTPステータスコード404(file not found)と共にエラーページを返します。',
#  'このエラーページの外観はErrorDocumentディレクティブで制御され、カスタムエラーレスポンスで説明されているように、柔軟な設定を行なうことができます。',
#  'File Not FoundFile Not Found必ず、リクエストされたURLに対応するファイルがファイルシステムに無いという場合が発生します。',
#  'これが起こるのにはいくつかの理由があります。',
#  '場合によっては、ドキュメントを別の場所に移動した結果であることがあります。',
#  'この場合は、クライアントにリソースの新しい位置を知らせるためにURLリダイレクションを使うのが最善の方法です。',
#  'そうすることによって、リソースは新しい位置に移動しているけれども、古いブックマークやリンクが動作し続けるようにすることができます。',
#  'URLリダイレクション"File Not Found" エラーのもう一つのよくある理由は、ブラウザへの直接入力やHTMLリンクからの偶発的なURLの入力間違いです。',
#  'Apacheはこの問題を改善するために、mod_spelingモジュール(意図的な綴り間違い)(訳注:正しくはspelling)を提供しています。',
#  'このモジュールが使用されているときは、"File Not Found" エラーを横取りして、似たファイル名のリソースを探します。',
#  'もし一つだけ見つかった場合はmod_spelingはクライアントに正しい位置を知らせるためにHTTPリダイレクトを送ります。',
#  'もし複数の「近い」ファイルが見つかった場合は、それら代替となりえるもののリストがクライアントに表示されます。',
#  'mod_spelingmod_spelingmod_spelingの非常に有用な機能は、大文字小文字を区別せずにファイル名を比較するものです。',
#  'これはURLとunixのファイルシステムが両方とも大文字小文字を区別するものである、ということをユーザが知らないシステムで役に立ちます。',
#  'ただし、時折のURL訂正程度で済まず、mod_spelingをより多く使用すると、サーバにさらなる負荷がかかります。',
#  'すべての「正しくない」リクエストの後にURLのリダイレクトとクライアントからの新しいリクエストがくることになりますから。',
#  'コンテンツの位置を決めようとするすべての試みが失敗すると、Apacheは、HTTPステータスコード404(file not found)と共にエラーページを返します。',
#  'このエラーページの外観はErrorDocumentディレクティブで制御され、カスタムエラーレスポンスで説明されているように、柔軟な設定を行なうことができます。',
#  'ErrorDocumentErrorDocumentカスタムエラーレスポンス翻訳済み言語:en|fr|ja|ko|tr翻訳済み言語:en|fr|ja|ko|tr翻訳済み言語:enfrjakotrコメントNotice:This is not a Q&A section.Comments placed here should be pointed towards suggestions on improving the documentation or server,and may be removed again by our moderators if they are either implemented or considered invalid/off-topic.Questions on how to manage the Apache HTTP Server should be directed at either our IRC channel,#httpd,on Freenode,or sent to ourmailing lists.コメントコメントNotice:This is not a Q&A section.Comments placed here should be pointed towards suggestions on improving the documentation or server,and may be removed again by our moderators if they are either implemented or considered invalid/off-topic.Questions on how to manage the Apache HTTP Server should be directed at either our IRC channel,#httpd,on Freenode,or sent to ourmailing lists.Notice:mailing listsCopyright 2019 The Apache Software Foundation.この文書はApache License,Version 2.0のライセンスで提供されています。',
#  '.モジュール|ディレクティブ|FAQ|用語|サイトマップCopyright 2019 The Apache Software Foundation.この文書はApache License,Version 2.0のライセンスで提供されています。',
#  '.Apache License,Version 2.0モジュール|ディレクティブ|FAQ|用語|サイトマップモジュールディレクティブFAQ用語サイトマップ']

# %%
# 文末記号のリスト（全角と半角）
sentence_endings = ['。', '！', '？', '.', '!', '?',"．"]
touten_symbols=["､",",","，","、"]

def is_sentence_ending(text):
    """指定された文字が文末記号かどうかを判断する"""
    return text[-1] in sentence_endings

# 結果を格納するリスト

grouped_lines=[]

temp_text=""
old_line=""
for line in lines:
    line=text_normalizer.normalize(line) #文字の正規化

    #重複行は削除
    if line==old_line:
        old_line=line
        continue

    old_line=line

    #if old_line[-1] in touten_symbols:
    #    temp_text+=line
    #    #print(temp_text)
    #    continue

    # ｡ などで終わらないlineの場合は､改行する
    if not is_sentence_ending(line):
        if temp_text!="":
            grouped_lines.append(temp_text)
            #print(temp_text)
        temp_text=""
        grouped_lines.append(line)
        #print(line)

    else:
        temp_text+=line
    #if not is_sentence_ending(temp_text):
    #    grouped_lines.append(temp_text)
    #    temp_text=""

text="\n".join(grouped_lines)
#text=do_filter(text)
print(text)


#TODO: まず、  をしてください(無料)。 のようになってしまう｡ 「､」で続くlineは､改行せずに統合すれば解決?
# Out:
# URLからファイルシステム上の位置へのマップ-Apache HTTPサーババージョン2.4モジュール|ディレクティブ|FAQ|用語|サイトマップApache HTTPサーババージョン2.4Apache>HTTPサーバ>ドキュメンテーション>バージョン2.4URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。最近更新された内容を見るには英語版をご覧下さい。この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。DocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。Apacheはこのために複数の方法を用意しています。Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。たとえば、ScriptAliasMatch^/~([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/~user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。ユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを~user/として参照できます。mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。http://www.example.com/~user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。中にはシンボル "~" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。mod_userdirはこの機能をサポートしていません。しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。この手法はリバースプロキシと呼ばれています。ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.examp ...
# .Apache License,Version 2.0モジュール|ディレクティブ|FAQ|用語|サイトマップモジュールディレクティブFAQ用語サイトマップ

# %%
grouped_lines
# Out:
# ['URLからファイルシステム上の位置へのマップ-Apache HTTPサーババージョン2.4モジュール|ディレクティブ|FAQ|用語|サイトマップApache HTTPサーババージョン2.4Apache>HTTPサーバ>ドキュメンテーション>バージョン2.4URLからファイルシステム上の位置へのマップ翻訳済み言語:en|fr|ja|ko|trこの日本語訳はすでに古くなっている可能性があります。最近更新された内容を見るには英語版をご覧下さい。この文書はApacheがリクエストのURLから送信するファイルのファイルシステム上の位置を決定する方法を説明します。関連するモジュールとディレクティブDocumentRootDocumentRoot外のファイルユーザディレクトリURLリダイレクションリバースプロキシリライトエンジンFile Not Found参照コメント関連するモジュールとディレクティブ関連モジュール関連ディレクティブmod_aliasmod_proxymod_rewritemod_userdirmod_spelingmod_vhost_aliasAliasAliasMatchCheckSpellingDocumentRootErrorDocumentOptionsProxyPassProxyPassReverseProxyPassReverseCookieDomainProxyPassReverseCookiePathRedirectRedirectMatchRewriteCondRewriteMatchScriptAliasScriptAliasMatchUserDirDocumentRootリクエストに対してどのファイルを送信するかを決定するときのApacheのデフォルトの動作は、リクエストのURL-Path(URLのホスト名とポート番号の後に続く部分)を取り出して設定ファイルで指定されているDocumentRootの最後に追加する、というものです。ですから、DocumentRootの下のディレクトリやファイルがウェブから見える基本のドキュメントの木構造をなします。Apacheにはサーバが複数のホストへのリクエストを受け取るバーチャルホストの機能もあります。この場合、それぞれのバーチャルホストに対して違うDocumentRootを指定することができます。また、mod_vhost_aliasモジュールにより提供されるディレクティブを使って、送信するためのコンテンツの場所をリクエストされたIPアドレスやホスト名から動的に決めることもできます。DocumentRoot外のファイルファイルシステム上の、厳密にはDocumentRootの下にはない部分へのウェブアクセスを許可する必要がある場合がよくあります。Apacheはこのために複数の方法を用意しています。Unixシステムでは、ファイルシステムの他の部分をシンボリックリンクを使ってDocumentRootの下に持ってくることができます。セキュリティ上の理由により、Apacheは該当するディレクトリのOptionsの設定にFollowSymLinksかSymLinksIfOwnerMatchがある場合にのみシンボリックリンクをたどります。代わりの方法として、Aliasディレクティブを使ってファイルシステムの任意の部分をウェブの空間にマップできます。たとえば、Alias/docs/var/webという設定のときは、URLhttp://www.example.com/docs/dir/file.htmlには/var/web/dir/file.htmlが送信されます。ScriptAliasも、対象となっているパスがCGIスクリプトとして扱われるという追加の効果以外は同じように動作します。もっと柔軟な設定が必要な状況では、AliasMatchディレクティブやScriptAliasMatchディレクティブを使って強力な正規表現に基づいたマッチと置換を行なうことができます。たとえば、ScriptAliasMatch^/~([a-zA-Z0-9]+)/cgi-bin/(.+)/home/$1/cgi-bin/$2はhttp://example.com/~user/cgi-bin/script.cgiへのリクエストを/home/user/cgi-bin/script.cgiというパスへマップし、このマップの結果としてのファイルをCGIスクリプトとして扱います。ユーザディレクトリ伝統的にUnixシステムではユーザuserのホームディレクトリを~user/として参照できます。mod_userdirモジュールはこの概念をウェブに拡張して、それぞれのユーザのホームディレクトリのファイルを以下のようなURLを使ってアクセスできるようにします。http://www.example.com/~user/file.htmlセキュリティの観点から、ウェブからユーザのホームディレクトリへ直接アクセスできるようにすることは適切ではありません。ですから、UserDirディレクティブにはユーザのホームディレクトリの下の、ウェブファイルの置かれているディレクトリを指定します。デフォルトの設定のUserdir public_htmlを使うと、上のURLは/home/user/public_html/file.htmlというようなファイルにマップされます。ここで、/home/user/は/etc/passwdで指定されているユーザのホームディレクトリです。Userdirには、/etc/passwdにホームディレクトリの位置が書かれていないシステムでも使うことのできる他の形式もあります。中にはシンボル "~" (%7eのように符号化されることが多い)を格好が悪いと思って、ユーザのディレクトリを表すために別の文字列の使用を好む人がいます。mod_userdirはこの機能をサポートしていません。しかし、ユーザのホームディレクトリが規則的な構成のときは、AliasMatchを使って望みの効果を達成することができます。たとえば、http://www.example.com/upages/user/file.htmlが/home/user/public_html/file.htmlにマップされるようにするには、以下のようにAliasMatchディレクティブを使います:AliasMatch^/upages/([a-zA-Z0-9]+)/?(.*)/home/$1/public_html/$2URLリダイレクション上の節で説明した設定用のディレクティブはApacheにファイルシステムの特定の場所からコンテンツを取ってきてクライアントに送り返すようにします。ときには、その代わりにクライアントにリクエストされたコンテンツは別のURLにあることを知らせて、クライアントが新しいURLへ新しいリクエストを行なうようにする方が望ましいことがあります。これはリダイレクションと呼ばれていて、Redirectディレクティブにより実装されています。たとえば、DocumentRootの下のディレクトリ/foo/が新しいディレクトリ/bar/に移動したときは、以下のようにしてクライアントが新しい場所のコンテンツをリクエストするように指示することができます:Redirect permanent/foo/http://www.example.com/bar/これは、/foo/で始まるすべてのURL-Pathを、www.example.comサーバの/bar/が/foo/に置換されたものにリダイレクトします。サーバは自分自身のサーバだけでなく、どのサーバにでもクライアントをリダイレクトすることができます。Apacheはより複雑な書き換えの問題のために、RedirectMatchディレクティブを提供しています。たとえば、サイトのホームページを違うサイトにリダイレクトするけれど、他のリクエストはそのまま扱う、というときは以下の設定を使います:RedirectMatch permanent^/$http://www.example.com/startpage.htmlあるいは、一時的にサイトのすべてのページを他のサイトの特定のページへリダイレクトするときは、以下を使います:RedirectMatch temp.*http://othersite.example.com/startpage.htmlリバースプロキシApacheは遠隔地にあるドキュメントをローカルのサーバのURL空間に持ってくることもできます。この手法はリバースプロキシと呼ばれています。ウェブサーバが遠隔地のドキュメントを取得してクライアントに送り返すのがプロキシサーバの動作のように見えるからです。クライアントにはドキュメントがリバースプロキシサーバから送られてきているように見える点が通常のプロキシとは異なります。次の例では、クライアントが/foo/ディレクトリの下にあるドキュメントをリクエストすると、サーバがinternal.example.comの/bar/ディレクトリから取得して、さもローカルサーバからのドキュメントのようにしてクライアントに返します。ProxyPass/foo/http://internal.example.com/bar/ProxyPassReverse/foo/http://internal.example.com/bar/ProxyPassReverseCookieDomain internal.exa ...
#  '.Apache License,Version 2.0モジュール|ディレクティブ|FAQ|用語|サイトマップモジュールディレクティブFAQ用語サイトマップ']

# %%
line[-1]
# Out:
# '、'

# %%
line
# Out:
# '.Apache License,Version 2.0モジュール|ディレクティブ|FAQ|用語|サイトマップモジュールディレクティブFAQ用語サイトマップ'
